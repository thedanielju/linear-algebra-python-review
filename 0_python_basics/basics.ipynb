# %% [markdown]
# # by the end of this session, comfortable w/
# variables, number and text storage, printing, errors

# %%
a = 2 + 3
b = 10 * 4
c = 10/4
print(a, b, c)

# / always produces a float
# = means name binding, not equality 
# evaluates expression on the right, stores an object in memory representing that value
# name on left is bound to that object
# Out:
# 5 40 2.5

# %%
result = a+b+c
result
type(result) # lets us see the type
# Out:
# float

# %%
a = 2
b = 2.0
print(type(a), type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
numbers = [1, 2, 3, 4]

# %%
print(type(numbers), len(numbers))
# Out:
# <class 'list'> 4

# %%
print(numbers[1], numbers[3], numbers[-2])
# -1 = last element
# -2 = second to last element
# Out:
# 2 4 3

# %%
numbers[0] = 99
numbers
#lists are immediately mutable
# Out:
# [99, 2, 3, 4]

# %% [markdown]
# downstream:
# cocnepts that only make sense after foundational ideas
# advanced python features are downstream of linear algebra
